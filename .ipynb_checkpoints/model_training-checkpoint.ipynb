# %% [markdown]
# # TypeProfile: Model training notebook

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
import xgboost as xgb
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os

DATA_FILEPATH = os.path.join("Data","DSL-StrongPasswordData.csv")
FINAL_MDOEL_OUT_FILEPATH = os.path.join("Models","ty-v1.joblib")

# %% [markdown]
# ### Loading and Preparing the Data

# %%
df = pd.read_csv(DATA_FILEPATH)
df.head()
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0    s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1    s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2    s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3    s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4    s002             1    5    0.1249       0.2317       0.1068  0.0895
#
#    DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0  0.1674  0.0605  0.1169  ...  0.1349  0.1484  0.0135  0.0932  0.3515
# 1  0.1283  0.0589  0.0908  ...  0.1412  0.2558  0.1146  0.1146  0.2642
# 2  0.1291  0.0560  0.0821  ...  0.1621  0.2332  0.0711  0.1172  0.2705
# 3  0.2495  0.1436  0.1040  ...  0.1457  0.1629  0.0172  0.0866  0.2341
# 4  0.1676  0.0781  0.0903  ...  0.1312  0.1582  0.0270  0.0884  0.2517
#
#    UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# ...

# %%
def DataPreprocessing(data):
    ds = data.drop(columns = ["subject","sessionIndex","rep"])
    return ds

preprocessed_df = DataPreprocessing(df)
preprocessed_df.head()
# Out:
#    H.period  DD.period.t  UD.period.t     H.t  DD.t.i  UD.t.i     H.i  DD.i.e  \
# 0    0.1491       0.3979       0.2488  0.1069  0.1674  0.0605  0.1169  0.2212
# 1    0.1111       0.3451       0.2340  0.0694  0.1283  0.0589  0.0908  0.1357
# 2    0.1328       0.2072       0.0744  0.0731  0.1291  0.0560  0.0821  0.1542
# 3    0.1291       0.2515       0.1224  0.1059  0.2495  0.1436  0.1040  0.2038
# 4    0.1249       0.2317       0.1068  0.0895  0.1676  0.0781  0.0903  0.1589
#
#    UD.i.e     H.e  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  UD.n.l  \
# 0  0.1043  0.1417  ...  0.1349  0.1484  0.0135  0.0932  0.3515  0.2583
# 1  0.0449  0.0829  ...  0.1412  0.2558  0.1146  0.1146  0.2642  0.1496
# 2  0.0721  0.0808  ...  0.1621  0.2332  0.0711  0.1172  0.2705  0.1533
# 3  0.0998  0.0900  ...  0.1457  0.1629  0.0172  0.0866  0.2341  0.1475
# 4  0.0686  0.0805  ...  0.1312  0.1582  0.0270  0.0884  0.2517  0.1633
#
#       H.l  DD.l.Return  UD.l.Return  H.Return
# ...

# %%
preprocessed_df.describe()
# Out:
#            H.period   DD.period.t   UD.period.t           H.t        DD.t.i  \
# count  20400.000000  20400.000000  20400.000000  20400.000000  20400.000000
# mean       0.093379      0.264148      0.170769      0.085727      0.169085
# std        0.029626      0.220534      0.226836      0.027424      0.123546
# min        0.001400      0.018700     -0.235800      0.009300      0.001100
# 25%        0.074400      0.146900      0.049800      0.066000      0.113600
# 50%        0.089500      0.205950      0.108700      0.081000      0.140400
# 75%        0.107900      0.306450      0.212400      0.099800      0.183900
# max        0.376100     12.506100     12.451700      0.241100      4.919700
#
#              UD.t.i           H.i        DD.i.e        UD.i.e           H.e  \
# count  20400.000000  20400.000000  20400.000000  20400.000000  20400.000000
# mean       0.083358      0.081565      0.159372      0.077806      0.089138
# ...

# %%
scaler = StandardScaler()
pca = PCA(n_components=3)

X = preprocessed_df.values
X_scaled = scaler.fit_transform(X)
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# ### Visualize the datapoints

# %%
pca_df = pd.DataFrame({"pca-1":X_pca[:,0],
                       "pca-2":X_pca[:,1],
                       "pca-3":X_pca[:,2],
                      "subject":df["subject"]})
pca_df.head()
# Out:
#       pca-1     pca-2     pca-3 subject
# 0  3.676007  5.512560 -0.599538    s002
# 1  3.071060  2.538983 -0.578942    s002
# 2  1.735232  3.338406 -1.019351    s002
# 3  3.036968  3.606492  0.137352    s002
# 4  2.853875  1.559078 -0.848879    s002

# %%
sns.set_theme(style="darkgrid")
sns.scatterplot(data = pca_df,
                x = "pca-1",y = "pca-2",legend = False)
plt.title("PCA Plot of Keystroke Features")
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_df['pca-1'], pca_df['pca-2'], pca_df['pca-3'])

plt.title('3D PCA of Keystroke Features')
plt.show()

# %% [markdown]
# ### Model Training

# %%
knn = KMeans(n_clusters = 3,random_state=4)

clusters = knn.fit_predict(X_scaled)
clusters
# Out:
# array([2, 2, 0, ..., 1, 1, 1], dtype=int32)

# %%
pca_df["cluster"] = clusters

sns.set_theme(style="darkgrid")
sns.scatterplot(data = pca_df,
                x = "pca-1",y = "pca-2",hue = "cluster",legend = True)
plt.title("PCA Plot of Keystroke Features")
plt.show()

# %%
preprocessed_df["cluster"] = clusters
preprocessed_df.head()
# Out:
#    H.period  DD.period.t  UD.period.t     H.t  DD.t.i  UD.t.i     H.i  DD.i.e  \
# 0    0.1491       0.3979       0.2488  0.1069  0.1674  0.0605  0.1169  0.2212
# 1    0.1111       0.3451       0.2340  0.0694  0.1283  0.0589  0.0908  0.1357
# 2    0.1328       0.2072       0.0744  0.0731  0.1291  0.0560  0.0821  0.1542
# 3    0.1291       0.2515       0.1224  0.1059  0.2495  0.1436  0.1040  0.2038
# 4    0.1249       0.2317       0.1068  0.0895  0.1676  0.0781  0.0903  0.1589
#
#    UD.i.e     H.e  ...  DD.a.n  UD.a.n     H.n  DD.n.l  UD.n.l     H.l  \
# 0  0.1043  0.1417  ...  0.1484  0.0135  0.0932  0.3515  0.2583  0.1338
# 1  0.0449  0.0829  ...  0.2558  0.1146  0.1146  0.2642  0.1496  0.0839
# 2  0.0721  0.0808  ...  0.2332  0.0711  0.1172  0.2705  0.1533  0.1085
# 3  0.0998  0.0900  ...  0.1629  0.0172  0.0866  0.2341  0.1475  0.0845
# 4  0.0686  0.0805  ...  0.1582  0.0270  0.0884  0.2517  0.1633  0.0903
#
#    DD.l.Return  UD.l.Return  H.Return  cluster
# ...

# %%
preprocessed_df.groupby("cluster").mean()
# Out:
#          H.period  DD.period.t  UD.period.t       H.t    DD.t.i    UD.t.i  \
# cluster
# 0        0.117744     0.246469     0.128726  0.116479  0.176197  0.059718
# 1        0.087190     0.222716     0.135526  0.075577  0.144607  0.069029
# 2        0.072540     0.566059     0.493519  0.074028  0.304584  0.230556
#
#               H.i    DD.i.e    UD.i.e       H.e  ...       H.a    DD.a.n  \
# cluster                                          ...
# 0        0.109513  0.174672  0.065159  0.119176  ...  0.140866  0.155966
# 1        0.073286  0.124044  0.050758  0.078307  ...  0.093264  0.124227
# 2        0.065037  0.342637  0.277600  0.083443  ...  0.102920  0.302875
#
#            UD.a.n       H.n    DD.n.l    UD.n.l       H.l  DD.l.Return  \
# cluster
# 0        0.015100  0.113982  0.192469  0.078487  0.118242     0.307053
# 1        0.030964  0.083926  0.168921  0.084995  0.090770     0.280776
# 2        0.199955  0.068402  0.437957  0.369555  0.070373     0.614458
#
# ...

# %%
def ClusterLabel(x):
    if x==0:
        label = "medium"
    elif x==1:
        label = "fast"
    else:
        label = "slow"
    return label

# %%
df["cluster_labels"] = df["cluster"].map(ClusterLabel)
df.head()
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0    s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1    s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2    s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3    s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4    s002             1    5    0.1249       0.2317       0.1068  0.0895
#
#    DD.t.i  UD.t.i     H.i  ...  UD.a.n     H.n  DD.n.l  UD.n.l     H.l  \
# 0  0.1674  0.0605  0.1169  ...  0.0135  0.0932  0.3515  0.2583  0.1338
# 1  0.1283  0.0589  0.0908  ...  0.1146  0.1146  0.2642  0.1496  0.0839
# 2  0.1291  0.0560  0.0821  ...  0.0711  0.1172  0.2705  0.1533  0.1085
# 3  0.2495  0.1436  0.1040  ...  0.0172  0.0866  0.2341  0.1475  0.0845
# 4  0.1676  0.0781  0.0903  ...  0.0270  0.0884  0.2517  0.1633  0.0903
#
#    DD.l.Return  UD.l.Return  H.Return  cluster  cluster_labels
# ...
